# %% [markdown]
# # 数据挖掘实验报告

# %% [markdown]
# - 产生-1···1间隔为0.05的向量 $ \vec x $

# %%
import numpy as np

# %%
x=np.linspace(-1,1,41)
print("x的值为:\n",x)
# Out:
# x的值为:
#  [-1.   -0.95 -0.9  -0.85 -0.8  -0.75 -0.7  -0.65 -0.6  -0.55 -0.5  -0.45
#  -0.4  -0.35 -0.3  -0.25 -0.2  -0.15 -0.1  -0.05  0.    0.05  0.1   0.15
#   0.2   0.25  0.3   0.35  0.4   0.45  0.5   0.55  0.6   0.65  0.7   0.75
#   0.8   0.85  0.9   0.95  1.  ]

# %% [markdown]
# - 计算方程$ y=x^2+3 $

# %%
y=x*x+3

# %%
print("y的值为:\n",y)
# Out:
# y的值为:
#  [ 4.      3.9025  3.81    3.7225  3.64    3.5625  3.49    3.4225  3.36
#   3.3025  3.25    3.2025  3.16    3.1225  3.09    3.0625  3.04    3.0225
#   3.01    3.0025  3.      3.0025  3.01    3.0225  3.04    3.0625  3.09
#   3.1225  3.16    3.2025  3.25    3.3025  3.36    3.4225  3.49    3.5625
#   3.64    3.7225  3.81    3.9025  4.    ]

# %% [markdown]
# - 绘制函数$ y=x^2+3 $的函数图像

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# - 随机产生大小为30\*30的随机矩阵$ A $

# %%
A=np.random.random((30,30))

# %%
print("矩阵A的值如下:\n",A)
# Out:
# 矩阵A的值如下:
#  [[  7.70295269e-01   8.83076752e-01   7.22608660e-01   5.56232297e-01
#     4.66574500e-01   8.72010183e-02   4.14026023e-01   9.25432819e-02
#     8.95597080e-01   1.18975323e-01   6.49855482e-01   9.37751788e-01
#     4.21253523e-01   7.95463307e-01   9.59202080e-01   5.96201745e-01
#     5.94162799e-01   2.13569899e-01   4.95126573e-01   3.02274895e-01
#     6.02309911e-01   3.82878564e-02   1.96726511e-01   2.15579788e-02
#     7.07519881e-01   1.03016921e-01   1.13075364e-01   4.29302421e-01
#     1.29233986e-01   1.30801532e-01]
#  [  9.94951801e-01   5.41647336e-01   1.70681024e-01   7.16739399e-01
#     4.21397298e-01   2.61138570e-01   5.18165465e-01   9.87032280e-02
#     3.15345356e-01   6.89903581e-01   1.10744238e-01   2.45091508e-01
#     1.35517137e-01   9.38517769e-01   6.61992054e-01   2.13378318e-01
#     9.93587050e-03   1.06784716e-01   3.56735975e-01   9.57145431e-01
#     7.23283679e-01   9.16376108e-01   8.35690835e-01   7.57832714e-01
# ...

# %% [markdown]
# - 绘制箱形图

# %%
A.shape
# Out:
# (30, 30)

# %%
import pandas as pd

# %%
df=pd.DataFrame(A)

# %%
df
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.770295  0.883077  0.722609  0.556232  0.466574  0.087201  0.414026
# 1   0.994952  0.541647  0.170681  0.716739  0.421397  0.261139  0.518165
# 2   0.157338  0.093531  0.384617  0.039003  0.055920  0.907766  0.569647
# 3   0.211008  0.479650  0.627085  0.272665  0.420325  0.765425  0.391020
# 4   0.889797  0.441902  0.392264  0.034683  0.708399  0.532446  0.609874
# 5   0.414096  0.745331  0.253451  0.516724  0.296367  0.220777  0.023007
# 6   0.243837  0.457204  0.949171  0.419818  0.783314  0.591585  0.863656
# 7   0.516661  0.465779  0.067586  0.615646  0.015381  0.735079  0.526035
# 8   0.352368  0.803365  0.063127  0.740853  0.478922  0.185756  0.716297
# 9   0.397446  0.462304  0.160825  0.885371  0.119578  0.500613  0.963019
# 10  0.833598  0.580282  0.332500  0.454804  0.702507  0.479363  0.947491
# 11  0.933914  0.351831  0.752572  0.296293  0.353525  0.971828  0.087132
# ...

# %%
df.boxplot()
plt.ylabel('y')
plt.xlabel('x')
plt.title('$A$')
plt.show()

# %% [markdown]
# - 在矩阵$ A $中随机选择100个数据

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-5fd2a589eb17> in <module>()
# ----> 1 B=np.random.sample(df)
#
# mtrand.pyx in mtrand.RandomState.random_sample()
#
# mtrand.pyx in mtrand.cont0_array()
#
# TypeError: 'Series' object cannot be interpreted as an integer
